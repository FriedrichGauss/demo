# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Markus Bunge**
#
# I am a data scientist with a financial firm

# %% [markdown]
# *I am interested in data science because I love to predict outcomes and learn how models operate.*

# %% [markdown]
# ### This code allows you to obtain the roots of a quadratic equation

# %%
import numpy as np
import math
def quadratic(a,b,c):
    pm = np.array([+1,-1])
    return (-b+pm*math.sqrt(b**2-4*a*c))/(2*a)
#Example (x^2 - 4x -5)
quadratic(1,-4,-5)
# Out:
# array([ 5., -1.])

# %% [markdown]
# ~~Mathematics is the queen of the sciences.~~
#
# * Mathematicians stand on each other's shoulders.
# * Life stands before me like an eternal spring with new and brilliant clothes.
#
# 1. It is not knowledge, but the act of learning, not possession but the act of getting there, which grants the greatest enjoyment.
# 2. Further, the dignity of the science itself seems to require that every possible means be explored for the solution of a problem so elegant and so celebrated.
#
# ![pikachu%20image.jpg](attachment:pikachu%20image.jpg)
#
# https://duckduckgo.com/?va=b&t=hc
